# %% [markdown]
# ##### Data Preprocessing

# %%
import preprocess_data

# %% [markdown]
# ##### Model Import and Training

# %%
import model
import utilities
import train

# %% [markdown]
# ##### Model Running

# %%
import run_on_sequence

# %% [markdown]
# ##### Run Model on other Data - Camvid

# %%
import run_on_sequence_camvid

# %% [markdown]
# ##### Run Model on other Data - Madison

# %%
import run_on_sequence_madison
# Out:
# WARNING:tensorflow:From /Users/raysmith/Documents/School/Graduate/Spring 2021/ECE 738/Final Project/ENet/model.py:53: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /Users/raysmith/Documents/School/Graduate/Spring 2021/ECE 738/Final Project/ENet/model.py:597: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...
